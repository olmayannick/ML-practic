# %% [markdown]
# # PANDAS İLE VERİ MANİPLASYONU

# %% [markdown]
# PANDAS İLE VERİ MANİPLAYYONU VE TEMEL GÖRÜNTÜ İŞLEME

# %%
import pandas as pd   
# print(pd.__version__)  2.1.4

df = csv_read = pd.read_csv('corona_dat.csv')

# %%
# df.head() baştan 5 satır
df.tail()
# Out:
#           date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 107   5/8/2020          222       23      336       11       7
# 108   5/9/2020          291       13      274       11       2
# 109  5/10/2020          430       35      305        6       2
# 110  5/11/2020          287        8      336        0       0
# 111  5/12/2020          333       32      341       21       0
#
#      Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay     US  \
# 107                    0        309      179         49  ...       25  32381
# 108                    3        241      196         40  ...       15  40777
# 109                    0        292      197         35  ...       10  24076
# 110                    0        333      114         68  ...       10  36341
# 111                    0        315      218         68  ...       15  20723
#
#      Uzbekistan  Venezuela  Vietnam  West Bank and Gaza  Western Sahara  \
# ...

# %%
df.sample(5) # rastgele 5 satır
# Out:
#          date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 31  2/22/2020            0        0        0        0       0
# 82  4/13/2020           61       36       99        8       0
# 24  2/15/2020            0        0        0        0       0
# 79  4/10/2020           37       24      174       32       0
# 13   2/4/2020            0        0        0        0       0
#
#     Antigua and Barbuda  Argentina  Armenia  Australia  ...  Uruguay     US  \
# 31                    0          0        0          0  ...        0      0
# 82                    2        120       41         37  ...       21  37584
# 24                    0          0        0          0  ...        0      0
# 79                    0        200       29        431  ...       29  39213
# 13                    0          0        0          1  ...        0      0
#
#     Uzbekistan  Venezuela  Vietnam  West Bank and Gaza  Western Sahara  Yemen  \
# ...

# %%
df.info() # veri hakkında bilgi
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Columns: 188 entries, date to Zimbabwe
# dtypes: int64(187), object(1)
# memory usage: 164.6+ KB

# %%
df.describe() # istatistiksel bilgiler
# Out:
#        Afghanistan     Albania     Algeria     Andorra      Angola  \
# count   112.000000  112.000000  112.000000  112.000000  112.000000
# mean     50.892857   14.187500   85.535714   12.267857    0.535714
# std      89.664073   15.585007  106.528593   17.384358    1.348530
# min       0.000000    0.000000   -5.000000   -1.000000    0.000000
# 25%       0.000000    0.000000    0.000000    0.000000    0.000000
# 50%       1.500000    8.000000   12.500000    0.500000    0.000000
# 75%      59.500000   27.250000  168.750000   22.250000    0.000000
# max     430.000000   58.000000  341.000000   97.000000    7.000000
#
#        Antigua and Barbuda   Argentina     Armenia    Australia      Austria  \
# count           112.000000  112.000000  112.000000   112.000000   112.000000
# mean              0.419643   78.071429   44.776786   119.178571   274.392857
# std               1.175105   98.391726   58.731594   200.384910   348.000760
# ...

# %%
df['Turkey'] # ya da df.Turkey
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 107    5308
# 108    4680
# 109    4800
# 110    4258
# 111    4866
# Name: Turkey, Length: 112, dtype: int64

# %%
df[['Turkey','Angola','Uruguay','China']] # ya da df.Turkey
# Out:
#      Turkey  Angola  Uruguay  China
# 0         0       0        0    593
# 1         0       0        0     98
# 2         0       0        0    291
# 3         0       0        0    505
# 4         0       0        0    693
# ..      ...     ...      ...    ...
# 107    5308       7       25     17
# 108    4680       2       15    148
# 109    4800       2       10     60
# 110    4258       0       10     32
# 111    4866       0       15     31
#
# [112 rows x 4 columns]

# %%
df2 = df['Turkey'] 
df2.plot()
# Out:
# <Axes: >

# %%
df3 = df[['Turkey','US','Uruguay','China', 'Germany']]
df3.plot()
# Out:
# <Axes: >

# %% [markdown]
# # tarihe göre sıralı olamyabilir sıralayak

# %%
df4 = df[['US','Turkey','Germany', 'Uruguay', 'date']]
df4.set_index('date', inplace=True)
df4
# Out:
#               US  Turkey  Germany  Uruguay
# date
# 1/22/2020      1       0        0        0
# 1/23/2020      0       0        0        0
# 1/24/2020      1       0        0        0
# 1/25/2020      0       0        0        0
# 1/26/2020      3       0        0        0
# ...          ...     ...      ...      ...
# 5/8/2020   32381    5308     1276       25
# 5/9/2020   40777    4680     2375       15
# 5/10/2020  24076    4800     1675       10
# 5/11/2020  36341    4258     2006       10
# 5/12/2020  20723    4866     2255       15
#
# [112 rows x 4 columns]

# %%
df4.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df4.cumsum(axis=0).plot() # kümülatif toplam
# Out:
# <Axes: xlabel='date'>

# %%
df5 = df[['Turkey','Germany','Argentina','Italy', 'date']]
df5.set_index('date', inplace=True)
df5.cumsum(axis=0).plot() # kümülatif toplam
# Out:
# <Axes: xlabel='date'>

# %%
df5['Turkey'].cumsum(axis=0).plot() # kümülatif toplam
# Out:
# <Axes: xlabel='date'>

# %%
df6= df5['Turkey'].cumsum(axis=0)
df5.sum(axis=0)
# Out:
# Turkey       244258
# Germany      328109
# Argentina      8744
# Italy        361166
# dtype: int64

# %%
import seaborn as sns

# %%
# ülke bazında toplam vaka sayısı
df_haraketli = df[['Turkey','Germany','Argentina','Uzbekistan','China','Italy','Afghanistan ']]
# sns.barplot(x=df5.sum(axis=0).index, y=) #df5.sum(axis=0).values
df_haraketli.head
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[111], line 2
#       1 # ülke bazında toplam vaka sayısı
# ----> 2 df_haraketli = df[['Turkey','Germany','Argentina','Uzbekistan','China','Italy','Afghanistan ']]
#       3 # sns.barplot(x=df5.sum(axis=0).index, y=) #df5.sum(axis=0).values
#       4 df_haraketli.head
#
# File c:\Users\ahmi_\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\ahmi_\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
# ...

# %%
df_haraketli.tail()
# Out:
#      Turkey  Germany  Uruguay  China  Italy
# 107    5308     1276       25     17   4317
# 108    4680     2375       15    148   5285
# 109    4800     1675       10     60   3122
# 110    4258     2006       10     32   2324
# 111    4866     2255       15     31   4026

# %%
sns.lineplot(data=df_haraketli['Turkey'])
# Out:
# <Axes: ylabel='Turkey'>

# %%
# sns.histplot(data=df_haraketli['Turkey'])

# %%
print(df_haraketli.dtypes)
# Out:
# Turkey     int64
# Germany    int64
# Uruguay    int64
# China      int64
# Italy      int64
# dtype: object

# %%
import bar_chart_race as btr
btr.bar_chart_race(df_haraketli, filename='covid21.mp4',figsize=(10,8))
# Out:
# c:\Users\ahmi_\AppData\Local\Programs\Python\Python310\lib\site-packages\bar_chart_race\_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# c:\Users\ahmi_\AppData\Local\Programs\Python\Python310\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# c:\Users\ahmi_\AppData\Local\Programs\Python\Python310\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
